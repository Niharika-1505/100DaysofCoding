# %% [markdown]
# # First Solution

# %%
pip install xmlschema
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xmlschema in /usr/local/lib/python3.7/dist-packages (2.0.2)
# Requirement already satisfied: elementpath<4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from xmlschema) (3.0.2)

# %%
import xmlschema
import pandas as pd
from pprint import pprint

# %%
xs = xmlschema.XMLSchema('HSCOrgRefData.xsd')
dict_xs=xs.to_dict('Sample_file.xml')
# pprint(dict_xs)
to_convert_to_df = dict_xs['Organisations']
pprint(to_convert_to_df)
# Out:
# {'Organisation': [{'@orgRecordClass': 'RC2',
#                    'Date': [{'End': {'@value': '2013-03-31'},
#                              'Start': {'@value': '2006-10-01'},
#                              'Type': {'@value': 'Legal'}},
#                             {'Start': {'@value': '2006-10-01'},
#                              'Type': {'@value': 'Operational'}}],
#                    'GeoLoc': {'Location': {'AddrLn1': 'HIGHLAND ROAD',
#                                            'Country': 'ENGLAND',
#                                            'County': 'HAMPSHIRE',
#                                            'PostCode': 'PO4 9HU',
#                                            'Town': 'SOUTHSEA',
#                                            'UPRN': Decimal('1775039729')}},
#                    'LastChangeDate': {'@value': '2021-03-26'},
#                    'Name': 'EASTNEY HEALTH CENTRE',
#                    'OrgId': {'@assigningAuthorityName': 'HSCIC',
#                              '@extension': '5QCAH',
#                              '@root': '2.16.840.1.113883.2.1.3.2.4.18.48'},
#                    'Rels': {'Rel': [{'@id': 'RE6',
#                                      '@uniqueRelId': Decimal('178089'),
#                                      'Date': [{'End': {'@value': '2013-03-31'},
#                                                'Start': {'@value': '2006-10-01'},
#                                                'Type': {'@value': 'Legal'}},
#                                               {'End': {'@value': '2020-09-30'},
#                                                'Start': {'@value': '2006-10-01'},
#                                                'Type': {'@value': 'Operational'}}],
#                                      'Status': {'@value': 'Inactive'},
#                                      'Target': {'OrgId': {'@assigningAuthorityName': 'HSCIC',
#                                                           '@extension': '5QC',
#                                                           '@root': '2.16.840.1.113883.2.1.3.2.4.18.48'},
#                                                 'PrimaryRoleId': {'@id': 'RO179',
#                                                                   '@uniqueRoleId': Decimal('137676')}}}]},
#                    'Roles': {'Role': [{'@id': 'RO180',
#                                        '@primaryRole': True,
#                                        '@uniqueRoleId': Decimal('5785'),
#                                        'Date': [{'End': {'@value': '2013-03-31'},
#                                                  'Start': {'@value': '2006-10-01'},
#                                                  'Type': {'@value': 'Legal'}},
#                                                 {'Start': {'@value': '2006-10-01'},
#                                                  'Type': {'@value': 'Operational'}}],
#                                        'Status': {'@value': 'Active'}}]},
#                    'Status': {'@value': 'Active'},
#                    'Succs': {'Succ': [{'@uniqueSuccId': Decimal('171'),
#                                        'Date': {'Start': {'@value': '2006-10-01'},
#                                                 'Type': {'@value': 'Legal'}},
#                                        'Target': {'OrgId': {'@assigningAuthorityName': 'HSCIC',
#                                                             '@extension': '5FD51',
#                                                             '@root': '2.16.840.1.113883.2.1.3.2.4.18.48'},
#                                                   'PrimaryRoleId': {'@id': 'RO180',
#                                                                     '@uniqueRoleId': Decimal('44844')}},
#                                        'Type': 'Predecessor'}]}},
#                   {'@orgRecordClass': 'RC2',
#                    'Date': [{'End': {'@value': '2013-03-31'},
#                              'Start': {'@value': '2006-10-01'},
#                              'Type': {'@value': 'Legal'}},
#                             {'Start': {'@value': '2006-10-01'},
#                              'Type': {'@value': 'Operational'}}],
#                    'GeoLoc': {'Location': {'AddrLn1': 'VILLIERS ROAD',
#                                            'Country': 'ENGLAND',
#                                            'County': 'HAMPSHIRE',
#                                            'PostCode': 'PO5 2HG',
#                                            'Town': 'SOUTHSEA'}},
#                    'LastChangeDate': {'@value': '2021-03-26'},
#                    'Name': 'MERLIN CENTRE',
#                    'OrgId': {'@assigningAuthorityName': 'HSCIC',
#                              '@extension': '5QCAJ',
#                              '@root': '2.16.840.1.113883.2.1.3.2.4.18.48'},
#                    'Rels': {'Rel': [{'@id': 'RE6',
#                                      '@uniqueRelId': Decimal('177836'),
#                                      'Date': [{'End': {'@value': '2013-03-31'},
#                                                'Start': {'@value': '2006-10-01'},
#                                                'Type': {'@value': 'Legal'}},
#                                               {'End': {'@value': '2020-09-30'},
#                                                'Start': {'@value': '2006-10-01'},
#                                                'Type': {'@value': 'Operational'}}],
#                                      'Status': {'@value': 'Inactive'},
#                                      'Target': {'OrgId': {'@assigningAuthorityName': 'HSCIC',
#                                                           '@extension': '5QC',
#                                                           '@root': '2.16.840.1.113883.2.1.3.2.4.18.48'},
#                                                 'PrimaryRoleId': {'@id': 'RO179',
#                                                                   '@uniqueRoleId': Decimal('137676')}}}]},
#                    'Roles': {'Role': [{'@id': 'RO180',
#                                        '@primaryRole': True,
#                                        '@uniqueRoleId': Decimal('5786'),
#                                        'Date': [{'End': {'@value': '2013-03-31'},
#                                                  'Start': {'@value': '2006-10-01'},
#                                                  'Type': {'@value': 'Legal'}},
#                                                 {'Start': {'@value': '2006-10-01'},
#                                                  'Type': {'@value': 'Operational'}}],
#                                        'Status': {'@value': 'Active'}}]},
#                    'Status': {'@value': 'Active'},
#                    'Succs': {'Succ': [{'@uniqueSuccId': Decimal('1064'),
#                                        'Date': {'Start': {'@value': '2006-10-01'},
#                                                 'Type': {'@value': 'Legal'}},
#                                        'Target': {'OrgId': {'@assigningAuthorityName': 'HSCIC',
#                                                             '@extension': '5FD54',
#                                                             '@root': '2.16.840.1.113883.2.1.3.2.4.18.48'},
#                                                   'PrimaryRoleId': {'@id': 'RO180',
#                                                                     '@uniqueRoleId': Decimal('44845')}},
#                                        'Type': 'Predecessor'}]}},
#                   {'@orgRecordClass': 'RC2',
#                    'Date': [{'End': {'@value': '2013-03-31'},
#                              'Start': {'@value': '2006-10-01'},
#                              'Type': {'@value': 'Legal'}},
#                             {'Start': {'@value': '2006-10-01'},
#                              'Type': {'@value': 'Operational'}}],
#                    'GeoLoc': {'Location': {'AddrLn1': 'BATTENBURG AVENUE',
#                                            'Country': 'ENGLAND',
#                                            'County': 'HAMPSHIRE',
#                                            'PostCode': 'PO2 0TA',
#                                            'Town': 'PORTSMOUTH',
#                                            'UPRN': Decimal('1775099216')}},
#                    'LastChangeDate': {'@value': '2021-03-26'},
#                    'Name': 'BATTENBURG AVENUE CLINIC',
#                    'OrgId': {'@assigningAuthorityName': 'HSCIC',
#                              '@extension': '5QCAK',
#                              '@root': '2.16.840.1.113883.2.1.3.2.4.18.48'},
#                    'Rels': {'Rel': [{'@id': 'RE6',
#                                      '@uniqueRelId': Decimal('177889'),
#                                      'Date': [{'End': {'@value': '2013-03-31'},
#                                                'Start': {'@value': '2006-10-01'},
#                                                'Type': {'@value': 'Legal'}},
#                                               {'End': {'@value': '2020-09-30'},
#                                                'Start': {'@value': '2006-10-01'},
#                                                'Type': {'@value': 'Operational'}}],
#                                      'Status': {'@value': 'Inactive'},
#                                      'Target': {'OrgId': {'@assigningAuthorityName': 'HSCIC',
#                                                           '@extension': '5QC',
#                                                           '@root': '2.16.840.1.113883.2.1.3.2.4.18.48'},
#                                                 'PrimaryRoleId': {'@id': 'RO179',
#                                                                   '@uniqueRoleId': Decimal('137676')}}}]},
#                    'Roles': {'Role': [{'@id': 'RO180',
#                                        '@primaryRole': True,
#                                        '@uniqueRoleId': Decimal('5787'),
#                                        'Date': [{'End': {'@value': '2013-03-31'},
#                                                  'Start': {'@value': '2006-10-01'},
#                                                  'Type': {'@value': 'Legal'}},
#                                                 {'Start': {'@value': '2006-10-01'},
#                                                  'Type': {'@value': 'Operational'}}],
#                                        'Status': {'@value': 'Active'}}]},
#                    'Status': {'@value': 'Active'},
#                    'Succs': {'Succ': [{'@uniqueSuccId': Decimal('2658'),
#                                        'Date': {'Start': {'@value': '2006-10-01'},
#                                                 'Type': {'@value': 'Legal'}},
#                                        'Target': {'OrgId': {'@assigningAuthorityName': 'HSCIC',
#                                                             '@extension': '5FD55',
#                                                             '@root': '2.16.840.1.113883.2.1.3.2.4.18.48'},
#                                                   'PrimaryRoleId': {'@id': 'RO180',
#                                                                     '@uniqueRoleId': Decimal('44846')}},
#                                        'Type': 'Predecessor'}]}}]}

# %%
df=pd.DataFrame.from_dict(to_convert_to_df)

df1 = pd.DataFrame(df.Organisation.values.tolist())
df1 = df1.drop(['Roles','Rels','Succs','@orgRecordClass','LastChangeDate'], axis=1)
df1
# Out:
#                        Name  \
# 0     EASTNEY HEALTH CENTRE
# 1             MERLIN CENTRE
# 2  BATTENBURG AVENUE CLINIC
#
#                                                 Date  \
# 0  [{'Type': {'@value': 'Legal'}, 'Start': {'@val...
# 1  [{'Type': {'@value': 'Legal'}, 'Start': {'@val...
# 2  [{'Type': {'@value': 'Legal'}, 'Start': {'@val...
#
#                                                OrgId                Status  \
# 0  {'@root': '2.16.840.1.113883.2.1.3.2.4.18.48',...  {'@value': 'Active'}
# 1  {'@root': '2.16.840.1.113883.2.1.3.2.4.18.48',...  {'@value': 'Active'}
# 2  {'@root': '2.16.840.1.113883.2.1.3.2.4.18.48',...  {'@value': 'Active'}
#
#                                               GeoLoc
# 0  {'Location': {'AddrLn1': 'HIGHLAND ROAD', 'Tow...
# 1  {'Location': {'AddrLn1': 'VILLIERS ROAD', 'Tow...
# 2  {'Location': {'AddrLn1': 'BATTENBURG AVENUE', ...

# %%
df2 = pd.concat([df1, df1.OrgId.apply(lambda x: pd.Series(x))], axis=1)
df2 = df2.drop(['OrgId','@root','@assigningAuthorityName'],axis=1)
df2= df2.rename(columns={"@extension": "OrgId"})
df2
# Out:
#                        Name  \
# 0     EASTNEY HEALTH CENTRE
# 1             MERLIN CENTRE
# 2  BATTENBURG AVENUE CLINIC
#
#                                                 Date                Status  \
# 0  [{'Type': {'@value': 'Legal'}, 'Start': {'@val...  {'@value': 'Active'}
# 1  [{'Type': {'@value': 'Legal'}, 'Start': {'@val...  {'@value': 'Active'}
# 2  [{'Type': {'@value': 'Legal'}, 'Start': {'@val...  {'@value': 'Active'}
#
#                                               GeoLoc  OrgId
# 0  {'Location': {'AddrLn1': 'HIGHLAND ROAD', 'Tow...  5QCAH
# 1  {'Location': {'AddrLn1': 'VILLIERS ROAD', 'Tow...  5QCAJ
# 2  {'Location': {'AddrLn1': 'BATTENBURG AVENUE', ...  5QCAK

# %%
df3 = pd.concat([df2, df2.Date.apply(lambda x: pd.Series(x))], axis=1)
df3 = df3.drop('Date',axis=1)
df3
# Out:
#                        Name                Status  \
# 0     EASTNEY HEALTH CENTRE  {'@value': 'Active'}
# 1             MERLIN CENTRE  {'@value': 'Active'}
# 2  BATTENBURG AVENUE CLINIC  {'@value': 'Active'}
#
#                                               GeoLoc  OrgId  \
# 0  {'Location': {'AddrLn1': 'HIGHLAND ROAD', 'Tow...  5QCAH
# 1  {'Location': {'AddrLn1': 'VILLIERS ROAD', 'Tow...  5QCAJ
# 2  {'Location': {'AddrLn1': 'BATTENBURG AVENUE', ...  5QCAK
#
#                                                    0  \
# 0  {'Type': {'@value': 'Legal'}, 'Start': {'@valu...
# 1  {'Type': {'@value': 'Legal'}, 'Start': {'@valu...
# 2  {'Type': {'@value': 'Legal'}, 'Start': {'@valu...
#
#                                                    1
# 0  {'Type': {'@value': 'Operational'}, 'Start': {...
# 1  {'Type': {'@value': 'Operational'}, 'Start': {...
# 2  {'Type': {'@value': 'Operational'}, 'Start': {...

# %%
df4 = pd.concat([df3, df3[0].apply(lambda x: pd.Series(x))], axis=1)
df4 = df4.drop([0,'Type'],axis=1)
df4
# Out:
#                        Name                Status  \
# 0     EASTNEY HEALTH CENTRE  {'@value': 'Active'}
# 1             MERLIN CENTRE  {'@value': 'Active'}
# 2  BATTENBURG AVENUE CLINIC  {'@value': 'Active'}
#
#                                               GeoLoc  OrgId  \
# 0  {'Location': {'AddrLn1': 'HIGHLAND ROAD', 'Tow...  5QCAH
# 1  {'Location': {'AddrLn1': 'VILLIERS ROAD', 'Tow...  5QCAJ
# 2  {'Location': {'AddrLn1': 'BATTENBURG AVENUE', ...  5QCAK
#
#                                                    1  \
# 0  {'Type': {'@value': 'Operational'}, 'Start': {...
# 1  {'Type': {'@value': 'Operational'}, 'Start': {...
# 2  {'Type': {'@value': 'Operational'}, 'Start': {...
#
#                       Start                       End
# 0  {'@value': '2006-10-01'}  {'@value': '2013-03-31'}
# 1  {'@value': '2006-10-01'}  {'@value': '2013-03-31'}
# 2  {'@value': '2006-10-01'}  {'@value': '2013-03-31'}

# %%
df5 = pd.concat([df4, df4.Start.apply(lambda x: pd.Series(x))], axis=1)
df5 = df5.drop('Start',axis=1)
df5 = df5.rename(columns={"@value": "Legal_Start_Date"})
df5
# Out:
#                        Name                Status  \
# 0     EASTNEY HEALTH CENTRE  {'@value': 'Active'}
# 1             MERLIN CENTRE  {'@value': 'Active'}
# 2  BATTENBURG AVENUE CLINIC  {'@value': 'Active'}
#
#                                               GeoLoc  OrgId  \
# 0  {'Location': {'AddrLn1': 'HIGHLAND ROAD', 'Tow...  5QCAH
# 1  {'Location': {'AddrLn1': 'VILLIERS ROAD', 'Tow...  5QCAJ
# 2  {'Location': {'AddrLn1': 'BATTENBURG AVENUE', ...  5QCAK
#
#                                                    1  \
# 0  {'Type': {'@value': 'Operational'}, 'Start': {...
# 1  {'Type': {'@value': 'Operational'}, 'Start': {...
# 2  {'Type': {'@value': 'Operational'}, 'Start': {...
#
#                         End Legal_Start_Date
# 0  {'@value': '2013-03-31'}       2006-10-01
# 1  {'@value': '2013-03-31'}       2006-10-01
# 2  {'@value': '2013-03-31'}       2006-10-01

# %%
df6 = pd.concat([df5, df5.End.apply(lambda x: pd.Series(x))], axis=1)
df6 = df6.drop('End',axis=1)
df6 = df6.rename(columns={"@value": "Legal_End_Date"})
df6
# Out:
#                        Name                Status  \
# 0     EASTNEY HEALTH CENTRE  {'@value': 'Active'}
# 1             MERLIN CENTRE  {'@value': 'Active'}
# 2  BATTENBURG AVENUE CLINIC  {'@value': 'Active'}
#
#                                               GeoLoc  OrgId  \
# 0  {'Location': {'AddrLn1': 'HIGHLAND ROAD', 'Tow...  5QCAH
# 1  {'Location': {'AddrLn1': 'VILLIERS ROAD', 'Tow...  5QCAJ
# 2  {'Location': {'AddrLn1': 'BATTENBURG AVENUE', ...  5QCAK
#
#                                                    1 Legal_Start_Date  \
# 0  {'Type': {'@value': 'Operational'}, 'Start': {...       2006-10-01
# 1  {'Type': {'@value': 'Operational'}, 'Start': {...       2006-10-01
# 2  {'Type': {'@value': 'Operational'}, 'Start': {...       2006-10-01
#
#   Legal_End_Date
# 0     2013-03-31
# 1     2013-03-31
# 2     2013-03-31

# %%
df7 = pd.concat([df6, df6[1].apply(lambda x: pd.Series(x))], axis=1)
df7 = df7.drop([1,'Type'],axis=1)
df7
# Out:
#                        Name                Status  \
# 0     EASTNEY HEALTH CENTRE  {'@value': 'Active'}
# 1             MERLIN CENTRE  {'@value': 'Active'}
# 2  BATTENBURG AVENUE CLINIC  {'@value': 'Active'}
#
#                                               GeoLoc  OrgId Legal_Start_Date  \
# 0  {'Location': {'AddrLn1': 'HIGHLAND ROAD', 'Tow...  5QCAH       2006-10-01
# 1  {'Location': {'AddrLn1': 'VILLIERS ROAD', 'Tow...  5QCAJ       2006-10-01
# 2  {'Location': {'AddrLn1': 'BATTENBURG AVENUE', ...  5QCAK       2006-10-01
#
#   Legal_End_Date                     Start
# 0     2013-03-31  {'@value': '2006-10-01'}
# 1     2013-03-31  {'@value': '2006-10-01'}
# 2     2013-03-31  {'@value': '2006-10-01'}

# %%
df8 = pd.concat([df7, df7.Start.apply(lambda x: pd.Series(x))], axis=1)
df8 = df8.drop('Start',axis=1)
df8 = df8.rename(columns={"@value": "Operational_Start_Date"})
df8
# Out:
#                        Name                Status  \
# 0     EASTNEY HEALTH CENTRE  {'@value': 'Active'}
# 1             MERLIN CENTRE  {'@value': 'Active'}
# 2  BATTENBURG AVENUE CLINIC  {'@value': 'Active'}
#
#                                               GeoLoc  OrgId Legal_Start_Date  \
# 0  {'Location': {'AddrLn1': 'HIGHLAND ROAD', 'Tow...  5QCAH       2006-10-01
# 1  {'Location': {'AddrLn1': 'VILLIERS ROAD', 'Tow...  5QCAJ       2006-10-01
# 2  {'Location': {'AddrLn1': 'BATTENBURG AVENUE', ...  5QCAK       2006-10-01
#
#   Legal_End_Date Operational_Start_Date
# 0     2013-03-31             2006-10-01
# 1     2013-03-31             2006-10-01
# 2     2013-03-31             2006-10-01

# %%
df9 = pd.concat([df8, df8.Status.apply(lambda x: pd.Series(x))], axis=1)
df9 = df9.drop('Status',axis=1)
df9 = df9.rename(columns={"@value": "Status"})
df9
# Out:
#                        Name  \
# 0     EASTNEY HEALTH CENTRE
# 1             MERLIN CENTRE
# 2  BATTENBURG AVENUE CLINIC
#
#                                               GeoLoc  OrgId Legal_Start_Date  \
# 0  {'Location': {'AddrLn1': 'HIGHLAND ROAD', 'Tow...  5QCAH       2006-10-01
# 1  {'Location': {'AddrLn1': 'VILLIERS ROAD', 'Tow...  5QCAJ       2006-10-01
# 2  {'Location': {'AddrLn1': 'BATTENBURG AVENUE', ...  5QCAK       2006-10-01
#
#   Legal_End_Date Operational_Start_Date  Status
# 0     2013-03-31             2006-10-01  Active
# 1     2013-03-31             2006-10-01  Active
# 2     2013-03-31             2006-10-01  Active

# %%
df10 = pd.concat([df9, df9.GeoLoc.apply(lambda x: pd.Series(x))], axis=1)
df10 = df10.drop('GeoLoc',axis=1)
df10
# Out:
#                        Name  OrgId Legal_Start_Date Legal_End_Date  \
# 0     EASTNEY HEALTH CENTRE  5QCAH       2006-10-01     2013-03-31
# 1             MERLIN CENTRE  5QCAJ       2006-10-01     2013-03-31
# 2  BATTENBURG AVENUE CLINIC  5QCAK       2006-10-01     2013-03-31
#
#   Operational_Start_Date  Status  \
# 0             2006-10-01  Active
# 1             2006-10-01  Active
# 2             2006-10-01  Active
#
#                                             Location
# 0  {'AddrLn1': 'HIGHLAND ROAD', 'Town': 'SOUTHSEA...
# 1  {'AddrLn1': 'VILLIERS ROAD', 'Town': 'SOUTHSEA...
# 2  {'AddrLn1': 'BATTENBURG AVENUE', 'Town': 'PORT...

# %%
df11 = pd.concat([df10, df10.Location.apply(lambda x: pd.Series(x))], axis=1)
df11 = df11.drop('Location',axis=1)
df11
# Out:
#                        Name  OrgId Legal_Start_Date Legal_End_Date  \
# 0     EASTNEY HEALTH CENTRE  5QCAH       2006-10-01     2013-03-31
# 1             MERLIN CENTRE  5QCAJ       2006-10-01     2013-03-31
# 2  BATTENBURG AVENUE CLINIC  5QCAK       2006-10-01     2013-03-31
#
#   Operational_Start_Date  Status            AddrLn1        Town     County  \
# 0             2006-10-01  Active      HIGHLAND ROAD    SOUTHSEA  HAMPSHIRE
# 1             2006-10-01  Active      VILLIERS ROAD    SOUTHSEA  HAMPSHIRE
# 2             2006-10-01  Active  BATTENBURG AVENUE  PORTSMOUTH  HAMPSHIRE
#
#   PostCode  Country        UPRN
# 0  PO4 9HU  ENGLAND  1775039729
# 1  PO5 2HG  ENGLAND         NaN
# 2  PO2 0TA  ENGLAND  1775099216

# %%
final_df = df11.copy()
final_df.dtypes
# Out:
# Name                      object
# OrgId                     object
# Legal_Start_Date          object
# Legal_End_Date            object
# Operational_Start_Date    object
# Status                    object
# AddrLn1                   object
# Town                      object
# County                    object
# PostCode                  object
# Country                   object
# UPRN                      object
# dtype: object

# %% [markdown]
# # Alternative solution

# %%
lst = [
    {
        "Name": c.get("Name"),
        "OrgId": c.get("OrgId", {}).get("@extension"),
        "Legal_Start_Date": next((d for d in c.get("Date", []) if "Start" in d), {}).get("Start", {}).get("@value"),
        "Legal_End_Date": next((d for d in c.get("Date", []) if "End" in d), {}).get("End").get("@value"),
        "Operational_Start_Date":next((d for d in c.get("Date", []) if "Start" in d), {}).get("Start", {}).get("@value"),
        "Status": c.get("Status", {}).get("@value"),
        **c.get("GeoLoc", {}).get("Location", {}),
    }
    for c in to_convert_to_df["Organisation"]
]

final_dataframe = pd.DataFrame(lst)
final_dataframe
# Out:
#                        Name  OrgId Legal_Start_Date Legal_End_Date  \
# 0     EASTNEY HEALTH CENTRE  5QCAH       2006-10-01     2013-03-31
# 1             MERLIN CENTRE  5QCAJ       2006-10-01     2013-03-31
# 2  BATTENBURG AVENUE CLINIC  5QCAK       2006-10-01     2013-03-31
#
#   Operational_Start_Date  Status            AddrLn1        Town     County  \
# 0             2006-10-01  Active      HIGHLAND ROAD    SOUTHSEA  HAMPSHIRE
# 1             2006-10-01  Active      VILLIERS ROAD    SOUTHSEA  HAMPSHIRE
# 2             2006-10-01  Active  BATTENBURG AVENUE  PORTSMOUTH  HAMPSHIRE
#
#   PostCode  Country        UPRN
# 0  PO4 9HU  ENGLAND  1775039729
# 1  PO5 2HG  ENGLAND         NaN
# 2  PO2 0TA  ENGLAND  1775099216
